# %% [markdown]
# CNF Parser

# %%
def parse_cnf(in_data):
    cnf = list()
    cnf.append(list())
    maxvar = 0

    for line in in_data:
        tokens = line.split()
        if len(tokens) != 0 and tokens[0] not in ("p", "c", "%"):
            for tok in tokens:
                lit = int(tok)
                maxvar = max(maxvar, abs(lit))
                if lit == 0:
                    cnf.append(list())
                else:
                    lit = lit - 1 if lit > 0 else lit
                    cnf[-1].append(lit)

    assert len(cnf[-1]) == 0
    cnf.pop()
    cnf.pop()
    return cnf

# %%
from os import walk
import torch
import random 
import numpy as np
import time 
import torch.nn.functional as F

problems = []
for (dirpath, dirnames, filenames) in walk('sat_problems/uf20-91/'):
# for (dirpath, dirnames, filenames) in walk('sat_problems/uf250-1065/'):
    for f in filenames:
        with open(dirpath + '/' + f, 'r') as file:
            lines = file.readlines()
            
            problems.append(parse_cnf(lines))
            
def create_vars(cnf): 
    maxvar = 0
    for c in cnf:
        for l in c:
            maxvar = max(maxvar, l + 1)
    v_t = torch.tensor(np.random.normal(size=(maxvar,), scale=2.0), requires_grad=True)
    return v_t

# This is where the magic happens
def to_fuzzy(cnf, variables, N, T, S):
    # Create a single vector that first contains the truth values of the variables and then the negated
    # truth values, reversed (so that the indices match: -1 should be at the end in Python)
    variables = torch.cat([variables, reversed(1 - variables)])
    
    # Take, for each conjunct, the correct three truth values. This returns a #clauses x 3 matrix of truth values,
    # where element i, j is the truth values the t the j'th literal of the i'th clause
    indexed = torch.take(variables, cnf)
    
    # Compute the truth value of each disjunct by applying the S norm over the 1st dimension
    conjuncts = S(indexed)
    # Compute the truth value of SAT by applying the T norm over the truth value of the disjuncts
    truth = T(conjuncts)
    return truth

def n_clauses_satisfied(truth_tensor, problem):
    truth = truth_tensor.detach().numpy()
    n = 0
    not_satisfied = []
    for clause in problem:
        sat = False
        for l in clause:
            if l < 0:
                if truth[-l - 1] < 0.5:
                    sat = True
            elif truth[l] >= 0.5:
                sat = True
        if sat:
            n += 1
        else:
            not_satisfied.append(clause)
    return n, not_satisfied

N = lambda a: 1.0 - a
    
def extend_s(s):
    def to_return(a):
        s1 = s(a[:, 0], a[:, 1])
        for i in range(a.size()[1] - 2):
            s1 = s(s1, a[:, i+2])
        return s1
    return to_return

def extend_t(t):
    def to_return(a):
        t1 = t(a[0], a[1])
        for i in range(a.size()[0] - 2):
            t1 = t(t1, a[i+2])
        return t1
    return to_return
    
EPSILON = 0.00000001
# Godel norm
# T = lambda a: torch.min(a)
# S = lambda a: torch.max(a, dim=1)[0]

# Product norm
# T = lambda a: torch.sum(torch.log(a+EPSILON))
# S = lambda a: 1 - torch.prod(1 - a, dim=1)

# Luk
# T = lambda a: torch.clamp(torch.sum(a) + 1 - a.size()[0], min=0)
# S = lambda a: torch.clamp(torch.sum(a, dim=1), max=1)

# nilpotent
def nilpotent_t_norm(a):
    lowest_values = -torch.topk(-a, 2)[0]
    I = 1.0 * (torch.sum(lowest_values) > 1).double()
    return lowest_values[0] * I

def nilpotent_s_norm(a):
    highest_values = torch.topk(a, 2, dim=1)[0]
    I = (torch.sum(highest_values, dim=1) < 1.0).double()
    return highest_values[:, 0] * I + 1 - I

# T = nilpotent_t_norm
# S = nilpotent_s_norm

# Trigonometric
# T = lambda a: 2.0 / np.pi * torch.asin(torch.prod(torch.sin(a * np.pi / 2.0)))
# S = lambda a: 2.0 / np.pi * torch.acos(torch.prod(torch.cos(a * np.pi / 2.0), dim=1))

# Hamacher 0
# T = lambda a: 1 / (1 - a.size()[0] + torch.sum(1 / (a)))
# T = extend_t(lambda a, b: a * b / (a + b - a * b))
# T = lambda a: 1 / (1 - )
# S = extend_s(lambda a, b: (a + b - 2 * a * b) / (1 - a * b + EPSILON))

# Dombi 
# Note: Alpha = 1 gives the Hamacher product (ie, hamacher @ 0)
alpha = 1
# T = lambda a: 1 / (1 + torch.sum(((1-a) / a)**alpha)**(1/alpha))

# Dubois-Prade
# T = lambda a: torch.prod(a) / torch.clamp(torch.max(a), min=0.5)
# S = lambda a: (1 - torch.prod(1 - a, dim=1) - torch.clamp(torch.min(a, dim=1)[0], min=0.5)) / \
#     torch.clamp(torch.max(1 - a, dim=1)[0], min=0.5)

pa = 1
pb0 = -0.5

# pa = 6
# pb0 = -0.1

# Max Sigmoid
# y1 = torch.exp(-pa*(1+pb0)) + 1
# y2 = torch.exp(-pa * (1 - n + pb0)) + 1

# h = y1 / (y2 - y1)
# c = h * y2
# T = lambda a: F.logsigmoid(pa * (torch.sum(a) - a.size()[0] + 1 + pb0))
# S = lambda a: F.sigmoid(pa * (torch.sum(a, dim=1) + pb0))
# T = lambda a: c * F.sigmoid(pa * (torch.sum(a, dim=1) - a.size()[0] + 1 + pb0)) - h

# Prod sigmoid WITHOUT NORMALIZATION!!!!
# T = lambda a: F.logsigmoid(pa * (torch.prod(a) + pb0))
# S = lambda a: F.sigmoid(pa * (1 - torch.prod(1-a, dim=1) + pb0))

# y1 = 1 + torch.exp(-pa*)

# T = lambda a: torch.sigmoid(torch.sum(torch.log(a/(1-a))))
# S = lambda a: torch.sigmoid(torch.sum(torch.log(a/(1-a)), dim=1))

# General sigmoid
def sigmoid(f, pa):
    def _sigmoid(a):
        f0 = f(torch.zeros_like(a))
        f1 = f(torch.ones_like(a))
        y1 = torch.exp(-pa * (f1 + pb0)) + 1
        y2 = torch.exp(-pa * (f0 + pb0)) + 1
        return (y1/(y2 - y1)) * (y2 * torch.sigmoid(pa*(f(a) + pb0)) - 1)
    return _sigmoid

# T = sigmoid(lambda a: torch.sum(a) - a.size()[0] + 1)
S = sigmoid(lambda a: 1 - torch.prod(1-a, dim=1), pa)

# Yager
p = 2
# T = lambda a: torch.clamp(1-torch.sum((1-a)**p)**(1/p), min=0)
# S = lambda a: torch.clamp(torch.sum(a**p, dim=1)**(1/p), max=1)
# T = sigmoid(T, pa)

# RMSE
T = lambda a: 1-(EPSILON + torch.mean((1-a)**p))**(1/p)  
# S = lambda a: torch.mean(a**p, dim=1)**(1/p)

# MAE (Mean absolute error)
# T = lambda a: 1 - torch.mean(1 - a)
# T = lambda a: torch.mean(a)

clauses_satisfied = []
n_solved = 0
solved_in = []

for problem_n, problem in enumerate(problems):
    print(problem_n, '------------------------')
    start = time.time()
    logit_variables = create_vars(problem)
    optimizer = torch.optim.SGD([logit_variables], lr=10, momentum=0.9)
    problem = torch.tensor(problem)
    for iteration in range(3000):
        truth_variables = torch.sigmoid(logit_variables)
#         truth_variables = torch.clamp(logit_variables, min=0, max=1)
        if iteration % 100 == 0:
            n_c_sat, unsatisfied = n_clauses_satisfied(truth_variables, problem)
            if n_c_sat == len(problem):
                print('Solution found in', iteration, 'iterations')
                n_solved += 1
                solved_in.append(iteration)
                break
        optimizer.zero_grad()
        truth = -to_fuzzy(problem, truth_variables, N, T, S)
        if iteration % 1000 == 0:
            print('iteration', iteration)
            print('truth', truth.detach().numpy())
            print('n satisfied', n_c_sat)
        truth.backward()
        optimizer.step()
#     print('Solution:', torch.sigmoid(logit_variables))
    print('Time taken:', time.time() - start)
    print('Clauses satisfied:', n_c_sat)
    clauses_satisfied.append(n_c_sat)
print('Solved:', n_solved)
print('Avg solved clauses', np.mean(clauses_satisfied))
print('Avg iterations to solve', np.mean(solved_in))
# Out:
# 0 ------------------------
# iteration 0
# truth -0.8013504280286926
# n satisfied 78
# iteration 1000
# truth -0.9016298039186504
# n satisfied 89
# iteration 2000
# truth -0.9016321249376158
# n satisfied 89
# Time taken: 1.8781077861785889
# Clauses satisfied: 89
# 1 ------------------------
# iteration 0
# truth -0.8370198387477342
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.05974292755126953
# Clauses satisfied: 91
# 2 ------------------------
# iteration 0
# truth -0.8333511868976421
# n satisfied 87
# iteration 1000
# truth -0.9316553184255187
# n satisfied 90
# iteration 2000
# truth -0.9316674529931548
# n satisfied 90
# Time taken: 1.8498256206512451
# Clauses satisfied: 90
# 3 ------------------------
# iteration 0
# truth -0.8000812756253863
# n satisfied 83
# iteration 1000
# truth -0.9000364536228094
# n satisfied 88
# iteration 2000
# truth -0.9000377754862435
# n satisfied 88
# Time taken: 1.8510615825653076
# Clauses satisfied: 88
# 4 ------------------------
# iteration 0
# truth -0.7426579069364663
# n satisfied 74
# Solution found in 200 iterations
# Time taken: 0.10249805450439453
# Clauses satisfied: 91
# 5 ------------------------
# iteration 0
# truth -0.7383042299995561
# n satisfied 79
# Solution found in 200 iterations
# Time taken: 0.1063082218170166
# Clauses satisfied: 91
# 6 ------------------------
# iteration 0
# truth -0.7425882311316414
# n satisfied 77
# iteration 1000
# truth -0.9324193248879097
# n satisfied 90
# iteration 2000
# truth -0.9324253075891593
# n satisfied 90
# Time taken: 1.8326940536499023
# Clauses satisfied: 90
# 7 ------------------------
# iteration 0
# truth -0.8040726085379735
# n satisfied 77
# Solution found in 200 iterations
# Time taken: 0.1405177116394043
# Clauses satisfied: 91
# 8 ------------------------
# iteration 0
# truth -0.8009440967639754
# n satisfied 81
# iteration 1000
# truth -0.934888892162223
# n satisfied 90
# iteration 2000
# truth -0.9348975182998378
# n satisfied 90
# Time taken: 2.030735969543457
# Clauses satisfied: 90
# 9 ------------------------
# iteration 0
# truth -0.8072815111491263
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.08825945854187012
# Clauses satisfied: 91
# 10 ------------------------
# iteration 0
# truth -0.7518798445364779
# n satisfied 80
# iteration 1000
# truth -0.9169462750898656
# n satisfied 89
# iteration 2000
# truth -0.9169478501315989
# n satisfied 89
# Time taken: 2.025786876678467
# Clauses satisfied: 89
# 11 ------------------------
# iteration 0
# truth -0.7285503245640553
# n satisfied 74
# Solution found in 200 iterations
# Time taken: 0.10405373573303223
# Clauses satisfied: 91
# 12 ------------------------
# iteration 0
# truth -0.7708286562264608
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.0731661319732666
# Clauses satisfied: 91
# 13 ------------------------
# iteration 0
# truth -0.7649672661253434
# n satisfied 72
# Solution found in 100 iterations
# Time taken: 0.07887673377990723
# Clauses satisfied: 91
# 14 ------------------------
# iteration 0
# truth -0.7654127731374436
# n satisfied 71
# Solution found in 100 iterations
# Time taken: 0.04955720901489258
# Clauses satisfied: 91
# 15 ------------------------
# iteration 0
# truth -0.8260888082114146
# n satisfied 83
# Solution found in 100 iterations
# Time taken: 0.07893514633178711
# Clauses satisfied: 91
# 16 ------------------------
# iteration 0
# truth -0.8063499352146674
# n satisfied 80
# iteration 1000
# truth -0.9280924608424113
# n satisfied 90
# iteration 2000
# truth -0.9281070132987762
# n satisfied 90
# Time taken: 1.8549115657806396
# Clauses satisfied: 90
# 17 ------------------------
# iteration 0
# truth -0.80112024137878
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.057013750076293945
# Clauses satisfied: 91
# 18 ------------------------
# iteration 0
# truth -0.7760551883188579
# n satisfied 78
# iteration 1000
# truth -0.927556921226942
# n satisfied 90
# iteration 2000
# truth -0.9275653106398424
# n satisfied 90
# Time taken: 1.9123601913452148
# Clauses satisfied: 90
# 19 ------------------------
# iteration 0
# truth -0.8361228539693717
# n satisfied 83
# Solution found in 100 iterations
# Time taken: 0.056852102279663086
# Clauses satisfied: 91
# 20 ------------------------
# iteration 0
# truth -0.8136730291279344
# n satisfied 82
# iteration 1000
# truth -0.9259685862818742
# n satisfied 90
# iteration 2000
# truth -0.9259768557854019
# n satisfied 90
# Time taken: 2.592620611190796
# Clauses satisfied: 90
# 21 ------------------------
# iteration 0
# truth -0.7755607222134052
# n satisfied 76
# Solution found in 100 iterations
# Time taken: 0.05242204666137695
# Clauses satisfied: 91
# 22 ------------------------
# iteration 0
# truth -0.8371815412912269
# n satisfied 79
# iteration 1000
# truth -0.9117013817157681
# n satisfied 89
# iteration 2000
# truth -0.9117027620201833
# n satisfied 89
# Time taken: 3.3624327182769775
# Clauses satisfied: 89
# 23 ------------------------
# iteration 0
# truth -0.7992274534238188
# n satisfied 80
# Solution found in 600 iterations
# Time taken: 0.5422232151031494
# Clauses satisfied: 91
# 24 ------------------------
# iteration 0
# truth -0.7995700418416543
# n satisfied 84
# Solution found in 100 iterations
# Time taken: 0.13419246673583984
# Clauses satisfied: 91
# 25 ------------------------
# iteration 0
# truth -0.8117213550274136
# n satisfied 82
# iteration 1000
# truth -0.9425686346194369
# n satisfied 90
# iteration 2000
# truth -0.9425815119654763
# n satisfied 90
# Time taken: 2.257117986679077
# Clauses satisfied: 90
# 26 ------------------------
# iteration 0
# truth -0.7758965795757288
# n satisfied 78
# iteration 1000
# truth -0.946613084717607
# n satisfied 90
# iteration 2000
# truth -0.9466241540406657
# n satisfied 90
# Time taken: 3.306403398513794
# Clauses satisfied: 90
# 27 ------------------------
# iteration 0
# truth -0.8240286236605375
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.06297588348388672
# Clauses satisfied: 91
# 28 ------------------------
# iteration 0
# truth -0.7963921774923381
# n satisfied 84
# Solution found in 100 iterations
# Time taken: 0.08913826942443848
# Clauses satisfied: 91
# 29 ------------------------
# iteration 0
# truth -0.8414932393263737
# n satisfied 84
# Solution found in 200 iterations
# Time taken: 0.17344093322753906
# Clauses satisfied: 91
# 30 ------------------------
# iteration 0
# truth -0.797924281310832
# n satisfied 82
# iteration 1000
# truth -0.9367291681489294
# n satisfied 90
# Solution found in 2000 iterations
# Time taken: 2.200648069381714
# Clauses satisfied: 91
# 31 ------------------------
# iteration 0
# truth -0.829670533410968
# n satisfied 75
# Solution found in 100 iterations
# Time taken: 0.09989213943481445
# Clauses satisfied: 91
# 32 ------------------------
# iteration 0
# truth -0.8137429917854028
# n satisfied 79
# iteration 1000
# truth -0.926504419890202
# n satisfied 90
# iteration 2000
# truth -0.9265094298378572
# n satisfied 90
# Time taken: 2.017646074295044
# Clauses satisfied: 90
# 33 ------------------------
# iteration 0
# truth -0.7859638994250451
# n satisfied 76
# Solution found in 200 iterations
# Time taken: 0.12927556037902832
# Clauses satisfied: 91
# 34 ------------------------
# iteration 0
# truth -0.8071272454944636
# n satisfied 81
# iteration 1000
# truth -0.9321372008011756
# n satisfied 90
# iteration 2000
# truth -0.9321458810931822
# n satisfied 90
# Time taken: 2.0002644062042236
# Clauses satisfied: 90
# 35 ------------------------
# iteration 0
# truth -0.8204558667378954
# n satisfied 82
# Solution found in 200 iterations
# Time taken: 0.1210629940032959
# Clauses satisfied: 91
# 36 ------------------------
# iteration 0
# truth -0.7501284115171076
# n satisfied 77
# iteration 1000
# truth -0.935399499888524
# n satisfied 90
# iteration 2000
# truth -0.9354090795174987
# n satisfied 90
# Time taken: 2.24634051322937
# Clauses satisfied: 90
# 37 ------------------------
# iteration 0
# truth -0.8048508406907297
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.05715775489807129
# Clauses satisfied: 91
# 38 ------------------------
# iteration 0
# truth -0.8089193122074041
# n satisfied 83
# Solution found in 300 iterations
# Time taken: 0.17746639251708984
# Clauses satisfied: 91
# 39 ------------------------
# iteration 0
# truth -0.7896435150704595
# n satisfied 73
# Solution found in 100 iterations
# Time taken: 0.05588030815124512
# Clauses satisfied: 91
# 40 ------------------------
# iteration 0
# truth -0.8236036567146803
# n satisfied 81
# iteration 1000
# truth -0.9512065560412255
# n satisfied 90
# iteration 2000
# truth -0.9512182926586544
# n satisfied 90
# Time taken: 2.028109073638916
# Clauses satisfied: 90
# 41 ------------------------
# iteration 0
# truth -0.7773790704754038
# n satisfied 75
# iteration 1000
# truth -0.9297567657632746
# n satisfied 90
# iteration 2000
# truth -0.9297642158773275
# n satisfied 90
# Time taken: 2.5377209186553955
# Clauses satisfied: 90
# 42 ------------------------
# iteration 0
# truth -0.799835837287883
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.07189083099365234
# Clauses satisfied: 91
# 43 ------------------------
# iteration 0
# truth -0.7764226641930578
# n satisfied 79
# iteration 1000
# truth -0.9122147956969272
# n satisfied 89
# iteration 2000
# truth -0.9122163916865383
# n satisfied 89
# Time taken: 2.0048935413360596
# Clauses satisfied: 89
# 44 ------------------------
# iteration 0
# truth -0.8279395738834461
# n satisfied 86
# Solution found in 100 iterations
# Time taken: 0.09428906440734863
# Clauses satisfied: 91
# 45 ------------------------
# iteration 0
# truth -0.8017665560705336
# n satisfied 80
# iteration 1000
# truth -0.9311251770514922
# n satisfied 89
# iteration 2000
# truth -0.9311455752546455
# n satisfied 89
# Time taken: 3.2537131309509277
# Clauses satisfied: 89
# 46 ------------------------
# iteration 0
# truth -0.8623429884674052
# n satisfied 85
# Solution found in 100 iterations
# Time taken: 0.06880807876586914
# Clauses satisfied: 91
# 47 ------------------------
# iteration 0
# truth -0.7733014593593364
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.07479119300842285
# Clauses satisfied: 91
# 48 ------------------------
# iteration 0
# truth -0.805606147418758
# n satisfied 81
# iteration 1000
# truth -0.9432915701627623
# n satisfied 90
# iteration 2000
# truth -0.9432998417045637
# n satisfied 90
# Time taken: 2.399388074874878
# Clauses satisfied: 90
# 49 ------------------------
# iteration 0
# truth -0.7511951857981818
# n satisfied 74
# iteration 1000
# truth -0.9423570783700673
# n satisfied 90
# iteration 2000
# truth -0.9423669691542786
# n satisfied 90
# Time taken: 1.960916519165039
# Clauses satisfied: 90
# 50 ------------------------
# iteration 0
# truth -0.7544923610429825
# n satisfied 75
# Solution found in 100 iterations
# Time taken: 0.05872392654418945
# Clauses satisfied: 91
# 51 ------------------------
# iteration 0
# truth -0.8082424955937632
# n satisfied 82
# iteration 1000
# truth -0.9139118088592545
# n satisfied 89
# iteration 2000
# truth -0.9139145066697129
# n satisfied 89
# Time taken: 1.938730239868164
# Clauses satisfied: 89
# 52 ------------------------
# iteration 0
# truth -0.829406555797662
# n satisfied 78
# iteration 1000
# truth -0.9376915869424137
# n satisfied 90
# iteration 2000
# truth -0.9377011736899378
# n satisfied 90
# Time taken: 1.709665298461914
# Clauses satisfied: 90
# 53 ------------------------
# iteration 0
# truth -0.8390671556592023
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.0727238655090332
# Clauses satisfied: 91
# 54 ------------------------
# iteration 0
# truth -0.7994507611549675
# n satisfied 76
# Solution found in 100 iterations
# Time taken: 0.07678818702697754
# Clauses satisfied: 91
# 55 ------------------------
# iteration 0
# truth -0.8486639223450937
# n satisfied 84
# Solution found in 100 iterations
# Time taken: 0.06941366195678711
# Clauses satisfied: 91
# 56 ------------------------
# iteration 0
# truth -0.8411524279101543
# n satisfied 82
# iteration 1000
# truth -0.9379977715674657
# n satisfied 90
# iteration 2000
# truth -0.9380083748887952
# n satisfied 90
# Time taken: 1.838857650756836
# Clauses satisfied: 90
# 57 ------------------------
# iteration 0
# truth -0.7745240893559007
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.06848812103271484
# Clauses satisfied: 91
# 58 ------------------------
# iteration 0
# truth -0.7734735738245604
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.0753333568572998
# Clauses satisfied: 91
# 59 ------------------------
# iteration 0
# truth -0.8145276263100035
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.06652545928955078
# Clauses satisfied: 91
# 60 ------------------------
# iteration 0
# truth -0.8548476577636464
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.06806445121765137
# Clauses satisfied: 91
# 61 ------------------------
# iteration 0
# truth -0.7675251236604232
# n satisfied 77
# Solution found in 300 iterations
# Time taken: 0.19657063484191895
# Clauses satisfied: 91
# 62 ------------------------
# iteration 0
# truth -0.7755612375586839
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.06664800643920898
# Clauses satisfied: 91
# 63 ------------------------
# iteration 0
# truth -0.8198175886980306
# n satisfied 76
# Solution found in 100 iterations
# Time taken: 0.07283973693847656
# Clauses satisfied: 91
# 64 ------------------------
# iteration 0
# truth -0.8074447100846397
# n satisfied 79
# Solution found in 200 iterations
# Time taken: 0.1599268913269043
# Clauses satisfied: 91
# 65 ------------------------
# iteration 0
# truth -0.8708179237518554
# n satisfied 86
# Solution found in 100 iterations
# Time taken: 0.0755150318145752
# Clauses satisfied: 91
# 66 ------------------------
# iteration 0
# truth -0.7758482435914813
# n satisfied 75
# Solution found in 200 iterations
# Time taken: 0.10807919502258301
# Clauses satisfied: 91
# 67 ------------------------
# iteration 0
# truth -0.7918987066816888
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.06094765663146973
# Clauses satisfied: 91
# 68 ------------------------
# iteration 0
# truth -0.7790005638375181
# n satisfied 79
# Solution found in 100 iterations
# Time taken: 0.07478809356689453
# Clauses satisfied: 91
# 69 ------------------------
# iteration 0
# truth -0.7731036115588803
# n satisfied 82
# iteration 1000
# truth -0.9089495944596832
# n satisfied 89
# iteration 2000
# truth -0.9089536784036119
# n satisfied 89
# Time taken: 1.7752699851989746
# Clauses satisfied: 89
# 70 ------------------------
# iteration 0
# truth -0.8349176659297558
# n satisfied 83
# Solution found in 100 iterations
# Time taken: 0.0639193058013916
# Clauses satisfied: 91
# 71 ------------------------
# iteration 0
# truth -0.8243189565146783
# n satisfied 82
# iteration 1000
# truth -0.9414065617297365
# n satisfied 90
# iteration 2000
# truth -0.941417311053892
# n satisfied 90
# Time taken: 1.7419135570526123
# Clauses satisfied: 90
# 72 ------------------------
# iteration 0
# truth -0.7988745443050664
# n satisfied 82
# iteration 1000
# truth -0.9209445644712085
# n satisfied 89
# iteration 2000
# truth -0.9209468670074509
# n satisfied 89
# Time taken: 2.3384454250335693
# Clauses satisfied: 89
# 73 ------------------------
# iteration 0
# truth -0.8196405913334741
# n satisfied 74
# Solution found in 100 iterations
# Time taken: 0.07458233833312988
# Clauses satisfied: 91
# 74 ------------------------
# iteration 0
# truth -0.8018091097241478
# n satisfied 80
# iteration 1000
# truth -0.9365983028909026
# n satisfied 90
# iteration 2000
# truth -0.9366090228434907
# n satisfied 90
# Time taken: 1.8707215785980225
# Clauses satisfied: 90
# 75 ------------------------
# iteration 0
# truth -0.8063685683119654
# n satisfied 77
# Solution found in 100 iterations
# Time taken: 0.0768136978149414
# Clauses satisfied: 91
# 76 ------------------------
# iteration 0
# truth -0.841874478247889
# n satisfied 82
# iteration 1000
# truth -0.9354661778183776
# n satisfied 90
# iteration 2000
# truth -0.935475331302923
# n satisfied 90
# Time taken: 2.005067825317383
# Clauses satisfied: 90
# 77 ------------------------
# iteration 0
# truth -0.7876388014069925
# n satisfied 76
# iteration 1000
# truth -0.8991314564835694
# n satisfied 89
# iteration 2000
# truth -0.899132931157281
# n satisfied 89
# Time taken: 1.9652431011199951
# Clauses satisfied: 89
# 78 ------------------------
# iteration 0
# truth -0.8508752971189393
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.0655055046081543
# Clauses satisfied: 91
# 79 ------------------------
# iteration 0
# truth -0.7935920205325657
# n satisfied 79
# iteration 1000
# truth -0.9245543055685898
# n satisfied 90
# iteration 2000
# truth -0.9246443711591578
# n satisfied 90
# Time taken: 1.828111171722412
# Clauses satisfied: 90
# 80 ------------------------
# iteration 0
# truth -0.800714544011908
# n satisfied 74
# iteration 1000
# truth -0.9431376709418124
# n satisfied 90
# iteration 2000
# truth -0.9431553642153577
# n satisfied 90
# Time taken: 2.297063112258911
# Clauses satisfied: 90
# 81 ------------------------
# iteration 0
# truth -0.7825714618931028
# n satisfied 74
# Solution found in 100 iterations
# Time taken: 0.1181337833404541
# Clauses satisfied: 91
# 82 ------------------------
# iteration 0
# truth -0.7864301309190148
# n satisfied 79
# iteration 1000
# truth -0.9106361802173832
# n satisfied 89
# iteration 2000
# truth -0.9106480192322998
# n satisfied 89
# Time taken: 2.468212366104126
# Clauses satisfied: 89
# 83 ------------------------
# iteration 0
# truth -0.8048194346508301
# n satisfied 79
# Solution found in 200 iterations
# Time taken: 0.12766790390014648
# Clauses satisfied: 91
# 84 ------------------------
# iteration 0
# truth -0.8361086083080083
# n satisfied 85
# iteration 1000
# truth -0.926350507424109
# n satisfied 90
# iteration 2000
# truth -0.9263564550790855
# n satisfied 90
# Time taken: 1.6379351615905762
# Clauses satisfied: 90
# 85 ------------------------
# iteration 0
# truth -0.7749831172565942
# n satisfied 77
# Solution found in 100 iterations
# Time taken: 0.12193822860717773
# Clauses satisfied: 91
# 86 ------------------------
# iteration 0
# truth -0.823853386499942
# n satisfied 83
# Solution found in 100 iterations
# Time taken: 0.05701184272766113
# Clauses satisfied: 91
# 87 ------------------------
# iteration 0
# truth -0.7795480966932544
# n satisfied 79
# Solution found in 100 iterations
# Time taken: 0.06706428527832031
# Clauses satisfied: 91
# 88 ------------------------
# iteration 0
# truth -0.7799028330243887
# n satisfied 77
# iteration 1000
# truth -0.9266447243370624
# n satisfied 90
# iteration 2000
# truth -0.926656628318778
# n satisfied 90
# Time taken: 1.668853998184204
# Clauses satisfied: 90
# 89 ------------------------
# iteration 0
# truth -0.80761859912989
# n satisfied 81
# iteration 1000
# truth -0.9406888217004317
# n satisfied 90
# iteration 2000
# truth -0.9407074025072466
# n satisfied 90
# Time taken: 2.498222827911377
# Clauses satisfied: 90
# 90 ------------------------
# iteration 0
# truth -0.8380192550522516
# n satisfied 84
# Solution found in 100 iterations
# Time taken: 0.06931805610656738
# Clauses satisfied: 91
# 91 ------------------------
# iteration 0
# truth -0.8360062163125515
# n satisfied 84
# iteration 1000
# truth -0.9349526601663294
# n satisfied 90
# iteration 2000
# truth -0.9349844970592665
# n satisfied 90
# Time taken: 2.1447458267211914
# Clauses satisfied: 90
# 92 ------------------------
# iteration 0
# truth -0.8229731982943342
# n satisfied 82
# iteration 1000
# truth -0.9097128847589975
# n satisfied 89
# iteration 2000
# truth -0.9097162697498629
# n satisfied 89
# Time taken: 2.373866081237793
# Clauses satisfied: 89
# 93 ------------------------
# iteration 0
# truth -0.8138729999797812
# n satisfied 75
# iteration 1000
# truth -0.9501335719413515
# n satisfied 90
# iteration 2000
# truth -0.9501496586431214
# n satisfied 90
# Time taken: 1.681969165802002
# Clauses satisfied: 90
# 94 ------------------------
# iteration 0
# truth -0.788627104300585
# n satisfied 74
# Solution found in 100 iterations
# Time taken: 0.05207705497741699
# Clauses satisfied: 91
# 95 ------------------------
# iteration 0
# truth -0.810643229852031
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.05339837074279785
# Clauses satisfied: 91
# 96 ------------------------
# iteration 0
# truth -0.8236386144912035
# n satisfied 75
# Solution found in 100 iterations
# Time taken: 0.05713915824890137
# Clauses satisfied: 91
# 97 ------------------------
# iteration 0
# truth -0.7877662220210212
# n satisfied 74
# Solution found in 200 iterations
# Time taken: 0.14452433586120605
# Clauses satisfied: 91
# 98 ------------------------
# iteration 0
# truth -0.8020984686676569
# n satisfied 82
# Solution found in 500 iterations
# Time taken: 0.3257124423980713
# Clauses satisfied: 91
# 99 ------------------------
# iteration 0
# truth -0.8361981027210624
# n satisfied 84
# Solution found in 100 iterations
# Time taken: 0.05213665962219238
# Clauses satisfied: 91
# 100 ------------------------
# iteration 0
# truth -0.8026058874345613
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.08261251449584961
# Clauses satisfied: 91
# 101 ------------------------
# iteration 0
# truth -0.8330192811170665
# n satisfied 78
# iteration 1000
# truth -0.936315060318256
# n satisfied 90
# iteration 2000
# truth -0.9363237637023798
# n satisfied 90
# Time taken: 3.2549002170562744
# Clauses satisfied: 90
# 102 ------------------------
# iteration 0
# truth -0.8054396046052867
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.09692072868347168
# Clauses satisfied: 91
# 103 ------------------------
# iteration 0
# truth -0.8033491524080336
# n satisfied 79
# Solution found in 100 iterations
# Time taken: 0.050794363021850586
# Clauses satisfied: 91
# 104 ------------------------
# iteration 0
# truth -0.8429469715716417
# n satisfied 84
# iteration 1000
# truth -0.9324511603030131
# n satisfied 90
# iteration 2000
# truth -0.9324595844283592
# n satisfied 90
# Time taken: 2.772965669631958
# Clauses satisfied: 90
# 105 ------------------------
# iteration 0
# truth -0.7906116597857186
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.13997459411621094
# Clauses satisfied: 91
# 106 ------------------------
# iteration 0
# truth -0.7337802597278787
# n satisfied 75
# Solution found in 200 iterations
# Time taken: 0.3793168067932129
# Clauses satisfied: 91
# 107 ------------------------
# iteration 0
# truth -0.8170259179157355
# n satisfied 81
# iteration 1000
# truth -0.9388641637625628
# n satisfied 90
# iteration 2000
# truth -0.9388976563083168
# n satisfied 90
# Time taken: 2.695314884185791
# Clauses satisfied: 90
# 108 ------------------------
# iteration 0
# truth -0.814715935674676
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.07280802726745605
# Clauses satisfied: 91
# 109 ------------------------
# iteration 0
# truth -0.8081668094294794
# n satisfied 77
# iteration 1000
# truth -0.937758566844155
# n satisfied 90
# iteration 2000
# truth -0.937766847921389
# n satisfied 90
# Time taken: 2.4208974838256836
# Clauses satisfied: 90
# 110 ------------------------
# iteration 0
# truth -0.8201226442548346
# n satisfied 80
# iteration 1000
# truth -0.9391816856666938
# n satisfied 90
# iteration 2000
# truth -0.9391923416067745
# n satisfied 90
# Time taken: 2.3971991539001465
# Clauses satisfied: 90
# 111 ------------------------
# iteration 0
# truth -0.7959247825839559
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.048502206802368164
# Clauses satisfied: 91
# 112 ------------------------
# iteration 0
# truth -0.7883777613253038
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.046520233154296875
# Clauses satisfied: 91
# 113 ------------------------
# iteration 0
# truth -0.73708148565538
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.04736733436584473
# Clauses satisfied: 91
# 114 ------------------------
# iteration 0
# truth -0.7538248763705951
# n satisfied 77
# Solution found in 100 iterations
# Time taken: 0.04970288276672363
# Clauses satisfied: 91
# 115 ------------------------
# iteration 0
# truth -0.8394403211930237
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.06556248664855957
# Clauses satisfied: 91
# 116 ------------------------
# iteration 0
# truth -0.8170893274528108
# n satisfied 82
# iteration 1000
# truth -0.9269192330209217
# n satisfied 90
# iteration 2000
# truth -0.9269621880784586
# n satisfied 90
# Time taken: 1.4194254875183105
# Clauses satisfied: 90
# 117 ------------------------
# iteration 0
# truth -0.7664669502573789
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.0455780029296875
# Clauses satisfied: 91
# 118 ------------------------
# iteration 0
# truth -0.8416612218802412
# n satisfied 83
# iteration 1000
# truth -0.929191408732149
# n satisfied 90
# iteration 2000
# truth -0.9291995163242822
# n satisfied 90
# Time taken: 1.2839627265930176
# Clauses satisfied: 90
# 119 ------------------------
# iteration 0
# truth -0.7998831609439561
# n satisfied 81
# iteration 1000
# truth -0.9107715507222075
# n satisfied 89
# iteration 2000
# truth -0.9107742311390289
# n satisfied 89
# Time taken: 1.3523108959197998
# Clauses satisfied: 89
# 120 ------------------------
# iteration 0
# truth -0.784070281910382
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.03645133972167969
# Clauses satisfied: 91
# 121 ------------------------
# iteration 0
# truth -0.7909836622905069
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.05147838592529297
# Clauses satisfied: 91
# 122 ------------------------
# iteration 0
# truth -0.7737867475855331
# n satisfied 75
# Solution found in 100 iterations
# Time taken: 0.03923177719116211
# Clauses satisfied: 91
# 123 ------------------------
# iteration 0
# truth -0.7637151895899339
# n satisfied 76
# Solution found in 100 iterations
# Time taken: 0.0407872200012207
# Clauses satisfied: 91
# 124 ------------------------
# iteration 0
# truth -0.7887772202530804
# n satisfied 82
# iteration 1000
# truth -0.9045463047933169
# n satisfied 89
# iteration 2000
# truth -0.9045468514801068
# n satisfied 89
# Time taken: 1.3465230464935303
# Clauses satisfied: 89
# 125 ------------------------
# iteration 0
# truth -0.7631509559264164
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.05180692672729492
# Clauses satisfied: 91
# 126 ------------------------
# iteration 0
# truth -0.8223874324230895
# n satisfied 78
# iteration 1000
# truth -0.936043487472462
# n satisfied 90
# iteration 2000
# truth -0.9360572538869154
# n satisfied 90
# Time taken: 1.8673667907714844
# Clauses satisfied: 90
# 127 ------------------------
# iteration 0
# truth -0.7935728180159649
# n satisfied 78
# iteration 1000
# truth -0.9398444517343425
# n satisfied 90
# iteration 2000
# truth -0.9398536655716246
# n satisfied 90
# Time taken: 1.7862999439239502
# Clauses satisfied: 90
# 128 ------------------------
# iteration 0
# truth -0.7964081980083708
# n satisfied 82
# iteration 1000
# truth -0.9105001202502918
# n satisfied 89
# iteration 2000
# truth -0.9105036760941387
# n satisfied 89
# Time taken: 1.4960308074951172
# Clauses satisfied: 89
# 129 ------------------------
# iteration 0
# truth -0.8139338654709152
# n satisfied 79
# iteration 1000
# truth -0.9389274368477585
# n satisfied 90
# iteration 2000
# truth -0.9389368735964878
# n satisfied 90
# Time taken: 1.7334377765655518
# Clauses satisfied: 90
# 130 ------------------------
# iteration 0
# truth -0.8011450772894628
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.046201229095458984
# Clauses satisfied: 91
# 131 ------------------------
# iteration 0
# truth -0.7745168896642788
# n satisfied 78
# iteration 1000
# truth -0.9212117479587099
# n satisfied 90
# iteration 2000
# truth -0.9212349063231088
# n satisfied 90
# Time taken: 1.1858386993408203
# Clauses satisfied: 90
# 132 ------------------------
# iteration 0
# truth -0.8070060531288115
# n satisfied 78
# iteration 1000
# truth -0.8996899442595443
# n satisfied 88
# iteration 2000
# truth -0.8996917631416917
# n satisfied 88
# Time taken: 2.462644338607788
# Clauses satisfied: 88
# 133 ------------------------
# iteration 0
# truth -0.7966278516978264
# n satisfied 82
# iteration 1000
# truth -0.9396922046098978
# n satisfied 90
# iteration 2000
# truth -0.9397011047863979
# n satisfied 90
# Time taken: 2.089359760284424
# Clauses satisfied: 90
# 134 ------------------------
# iteration 0
# truth -0.8172463819429057
# n satisfied 82
# iteration 1000
# truth -0.9210837871792013
# n satisfied 90
# iteration 2000
# truth -0.9210880077675944
# n satisfied 90
# Time taken: 1.4590835571289062
# Clauses satisfied: 90
# 135 ------------------------
# iteration 0
# truth -0.7559285896736891
# n satisfied 78
# Solution found in 200 iterations
# Time taken: 0.09830808639526367
# Clauses satisfied: 91
# 136 ------------------------
# iteration 0
# truth -0.786816656494527
# n satisfied 76
# iteration 1000
# truth -0.9182465560662818
# n satisfied 89
# iteration 2000
# truth -0.9182493473202035
# n satisfied 89
# Time taken: 1.630988597869873
# Clauses satisfied: 89
# 137 ------------------------
# iteration 0
# truth -0.8030161420917304
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.11247587203979492
# Clauses satisfied: 91
# 138 ------------------------
# iteration 0
# truth -0.8145975651201302
# n satisfied 80
# Solution found in 200 iterations
# Time taken: 0.09914302825927734
# Clauses satisfied: 91
# 139 ------------------------
# iteration 0
# truth -0.7889787835263161
# n satisfied 80
# iteration 1000
# truth -0.9216941692680372
# n satisfied 90
# iteration 2000
# truth -0.9217019458990764
# n satisfied 90
# Time taken: 1.2357449531555176
# Clauses satisfied: 90
# 140 ------------------------
# iteration 0
# truth -0.7707268405025678
# n satisfied 73
# Solution found in 100 iterations
# Time taken: 0.04047036170959473
# Clauses satisfied: 91
# 141 ------------------------
# iteration 0
# truth -0.7766981565957675
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.039725542068481445
# Clauses satisfied: 91
# 142 ------------------------
# iteration 0
# truth -0.7929128457110846
# n satisfied 81
# iteration 1000
# truth -0.9270885468144034
# n satisfied 90
# iteration 2000
# truth -0.9270958030788906
# n satisfied 90
# Time taken: 1.6721315383911133
# Clauses satisfied: 90
# 143 ------------------------
# iteration 0
# truth -0.7951259098976984
# n satisfied 78
# iteration 1000
# truth -0.9394840246095044
# n satisfied 90
# iteration 2000
# truth -0.9394961206589723
# n satisfied 90
# Time taken: 1.291562795639038
# Clauses satisfied: 90
# 144 ------------------------
# iteration 0
# truth -0.7919135459290808
# n satisfied 79
# iteration 1000
# truth -0.9387128274564646
# n satisfied 90
# iteration 2000
# truth -0.9387467643219387
# n satisfied 90
# Time taken: 1.5765841007232666
# Clauses satisfied: 90
# 145 ------------------------
# iteration 0
# truth -0.8554036265393468
# n satisfied 80
# iteration 1000
# truth -0.9105207700181067
# n satisfied 89
# iteration 2000
# truth -0.9105229409740535
# n satisfied 89
# Time taken: 1.3491089344024658
# Clauses satisfied: 89
# 146 ------------------------
# iteration 0
# truth -0.8325156258468722
# n satisfied 87
# iteration 1000
# truth -0.9144585212670497
# n satisfied 89
# iteration 2000
# truth -0.9144666958311068
# n satisfied 89
# Time taken: 1.9747273921966553
# Clauses satisfied: 89
# 147 ------------------------
# iteration 0
# truth -0.8546204806812121
# n satisfied 85
# Solution found in 200 iterations
# Time taken: 0.09169888496398926
# Clauses satisfied: 91
# 148 ------------------------
# iteration 0
# truth -0.8219752436949701
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.04790639877319336
# Clauses satisfied: 91
# 149 ------------------------
# iteration 0
# truth -0.8337948065032583
# n satisfied 82
# Solution found in 200 iterations
# Time taken: 0.19303464889526367
# Clauses satisfied: 91
# 150 ------------------------
# iteration 0
# truth -0.812621352266025
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.16797924041748047
# Clauses satisfied: 91
# 151 ------------------------
# iteration 0
# truth -0.7829715659666059
# n satisfied 79
# Solution found in 800 iterations
# Time taken: 0.688408613204956
# Clauses satisfied: 91
# 152 ------------------------
# iteration 0
# truth -0.7301414158352317
# n satisfied 77
# iteration 1000
# truth -0.9350429022100759
# n satisfied 90
# iteration 2000
# truth -0.9350540933680254
# n satisfied 90
# Time taken: 1.7888875007629395
# Clauses satisfied: 90
# 153 ------------------------
# iteration 0
# truth -0.7364409438165057
# n satisfied 82
# iteration 1000
# truth -0.9356325789040013
# n satisfied 90
# iteration 2000
# truth -0.9356375676561146
# n satisfied 90
# Time taken: 1.8910174369812012
# Clauses satisfied: 90
# 154 ------------------------
# iteration 0
# truth -0.8132763958128993
# n satisfied 83
# Solution found in 100 iterations
# Time taken: 0.050542354583740234
# Clauses satisfied: 91
# 155 ------------------------
# iteration 0
# truth -0.8185286657281392
# n satisfied 78
# iteration 1000
# truth -0.9334442481483411
# n satisfied 90
# iteration 2000
# truth -0.9334522659577578
# n satisfied 90
# Time taken: 1.6304972171783447
# Clauses satisfied: 90
# 156 ------------------------
# iteration 0
# truth -0.8070421967115415
# n satisfied 81
# iteration 1000
# truth -0.8885813431571019
# n satisfied 87
# iteration 2000
# truth -0.8885813818167853
# n satisfied 87
# Time taken: 1.4289426803588867
# Clauses satisfied: 87
# 157 ------------------------
# iteration 0
# truth -0.8031183285548815
# n satisfied 83
# iteration 1000
# truth -0.9116741748629036
# n satisfied 89
# iteration 2000
# truth -0.911680172154955
# n satisfied 89
# Time taken: 1.3006384372711182
# Clauses satisfied: 89
# 158 ------------------------
# iteration 0
# truth -0.7972118839415835
# n satisfied 82
# iteration 1000
# truth -0.9383259649873223
# n satisfied 90
# iteration 2000
# truth -0.9383564534456325
# n satisfied 90
# Time taken: 1.9803380966186523
# Clauses satisfied: 90
# 159 ------------------------
# iteration 0
# truth -0.7932306266049913
# n satisfied 76
# iteration 1000
# truth -0.9364322962719951
# n satisfied 90
# iteration 2000
# truth -0.9364409694992601
# n satisfied 90
# Time taken: 1.3648993968963623
# Clauses satisfied: 90
# 160 ------------------------
# iteration 0
# truth -0.8264213964504022
# n satisfied 83
# Solution found in 100 iterations
# Time taken: 0.1683661937713623
# Clauses satisfied: 91
# 161 ------------------------
# iteration 0
# truth -0.7810159896576319
# n satisfied 81
# iteration 1000
# truth -0.8992205731480702
# n satisfied 89
# iteration 2000
# truth -0.8992340746805946
# n satisfied 89
# Time taken: 1.8867647647857666
# Clauses satisfied: 89
# 162 ------------------------
# iteration 0
# truth -0.8441391332224815
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.05002236366271973
# Clauses satisfied: 91
# 163 ------------------------
# iteration 0
# truth -0.798841753669653
# n satisfied 78
# iteration 1000
# truth -0.9137708421475897
# n satisfied 89
# iteration 2000
# truth -0.9137737653900408
# n satisfied 89
# Time taken: 1.638612985610962
# Clauses satisfied: 89
# 164 ------------------------
# iteration 0
# truth -0.734051666713962
# n satisfied 78
# iteration 1000
# truth -0.9314472004902693
# n satisfied 90
# iteration 2000
# truth -0.9314537183090952
# n satisfied 90
# Time taken: 1.864732027053833
# Clauses satisfied: 90
# 165 ------------------------
# iteration 0
# truth -0.7708172534495286
# n satisfied 77
# Solution found in 100 iterations
# Time taken: 0.06420230865478516
# Clauses satisfied: 91
# 166 ------------------------
# iteration 0
# truth -0.784517901098074
# n satisfied 78
# Solution found in 200 iterations
# Time taken: 0.0942232608795166
# Clauses satisfied: 91
# 167 ------------------------
# iteration 0
# truth -0.812478241476355
# n satisfied 83
# iteration 1000
# truth -0.9366523194884834
# n satisfied 90
# iteration 2000
# truth -0.9366610534197705
# n satisfied 90
# Time taken: 1.7264628410339355
# Clauses satisfied: 90
# 168 ------------------------
# iteration 0
# truth -0.8233397121716155
# n satisfied 83
# iteration 1000
# truth -0.9279908049931733
# n satisfied 90
# iteration 2000
# truth -0.9279996239355838
# n satisfied 90
# Time taken: 1.377854824066162
# Clauses satisfied: 90
# 169 ------------------------
# iteration 0
# truth -0.8128466417832154
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.048661231994628906
# Clauses satisfied: 91
# 170 ------------------------
# iteration 0
# truth -0.8043560468270408
# n satisfied 84
# iteration 1000
# truth -0.9378754124799598
# n satisfied 90
# iteration 2000
# truth -0.9378871907568321
# n satisfied 90
# Time taken: 1.398514747619629
# Clauses satisfied: 90
# 171 ------------------------
# iteration 0
# truth -0.7496133639390772
# n satisfied 75
# Solution found in 100 iterations
# Time taken: 0.04236149787902832
# Clauses satisfied: 91
# 172 ------------------------
# iteration 0
# truth -0.8402903044507836
# n satisfied 83
# Solution found in 100 iterations
# Time taken: 0.042025089263916016
# Clauses satisfied: 91
# 173 ------------------------
# iteration 0
# truth -0.7955771257853683
# n satisfied 82
# iteration 1000
# truth -0.9342818950344423
# n satisfied 90
# iteration 2000
# truth -0.9342879379212612
# n satisfied 90
# Time taken: 1.3958392143249512
# Clauses satisfied: 90
# 174 ------------------------
# iteration 0
# truth -0.8083566382941125
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.04901742935180664
# Clauses satisfied: 91
# 175 ------------------------
# iteration 0
# truth -0.8091601077126533
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.04777240753173828
# Clauses satisfied: 91
# 176 ------------------------
# iteration 0
# truth -0.7875553577007878
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.057280540466308594
# Clauses satisfied: 91
# 177 ------------------------
# iteration 0
# truth -0.7929668981540443
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.04831743240356445
# Clauses satisfied: 91
# 178 ------------------------
# iteration 0
# truth -0.834255430260696
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.04853534698486328
# Clauses satisfied: 91
# 179 ------------------------
# iteration 0
# truth -0.794209008075011
# n satisfied 78
# iteration 1000
# truth -0.9313836172834061
# n satisfied 90
# iteration 2000
# truth -0.9313903935712069
# n satisfied 90
# Time taken: 1.3729376792907715
# Clauses satisfied: 90
# 180 ------------------------
# iteration 0
# truth -0.8382606137884367
# n satisfied 84
# Solution found in 400 iterations
# Time taken: 0.18717074394226074
# Clauses satisfied: 91
# 181 ------------------------
# iteration 0
# truth -0.7675678523665811
# n satisfied 77
# Solution found in 100 iterations
# Time taken: 0.05674290657043457
# Clauses satisfied: 91
# 182 ------------------------
# iteration 0
# truth -0.8108616720335589
# n satisfied 75
# iteration 1000
# truth -0.9373330472111968
# n satisfied 90
# iteration 2000
# truth -0.9373406095633001
# n satisfied 90
# Time taken: 1.4491336345672607
# Clauses satisfied: 90
# 183 ------------------------
# iteration 0
# truth -0.7289910968011284
# n satisfied 73
# Solution found in 100 iterations
# Time taken: 0.05189847946166992
# Clauses satisfied: 91
# 184 ------------------------
# iteration 0
# truth -0.7878739795455909
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.0528719425201416
# Clauses satisfied: 91
# 185 ------------------------
# iteration 0
# truth -0.7713311464507393
# n satisfied 77
# Solution found in 200 iterations
# Time taken: 0.09637069702148438
# Clauses satisfied: 91
# 186 ------------------------
# iteration 0
# truth -0.8097761540863289
# n satisfied 82
# iteration 1000
# truth -0.9001853833949215
# n satisfied 88
# iteration 2000
# truth -0.9001868713994876
# n satisfied 88
# Time taken: 1.4221210479736328
# Clauses satisfied: 88
# 187 ------------------------
# iteration 0
# truth -0.7646721619958464
# n satisfied 79
# Solution found in 200 iterations
# Time taken: 0.0864109992980957
# Clauses satisfied: 91
# 188 ------------------------
# iteration 0
# truth -0.7521359638039095
# n satisfied 75
# iteration 1000
# truth -0.924702544595235
# n satisfied 90
# iteration 2000
# truth -0.9247309488626256
# n satisfied 90
# Time taken: 1.635502815246582
# Clauses satisfied: 90
# 189 ------------------------
# iteration 0
# truth -0.8170360974332531
# n satisfied 86
# Solution found in 200 iterations
# Time taken: 0.09546303749084473
# Clauses satisfied: 91
# 190 ------------------------
# iteration 0
# truth -0.7703345379726481
# n satisfied 82
# Solution found in 200 iterations
# Time taken: 0.09874486923217773
# Clauses satisfied: 91
# 191 ------------------------
# iteration 0
# truth -0.7236112429604521
# n satisfied 73
# Solution found in 200 iterations
# Time taken: 0.09745240211486816
# Clauses satisfied: 91
# 192 ------------------------
# iteration 0
# truth -0.8334397178655952
# n satisfied 81
# iteration 1000
# truth -0.9384688821101814
# n satisfied 90
# iteration 2000
# truth -0.938477352188056
# n satisfied 90
# Time taken: 1.4053435325622559
# Clauses satisfied: 90
# 193 ------------------------
# iteration 0
# truth -0.7705369303711211
# n satisfied 76
# Solution found in 100 iterations
# Time taken: 0.049546003341674805
# Clauses satisfied: 91
# 194 ------------------------
# iteration 0
# truth -0.8132992753758492
# n satisfied 79
# iteration 1000
# truth -0.9269304460318266
# n satisfied 90
# iteration 2000
# truth -0.9269453960246676
# n satisfied 90
# Time taken: 2.3084330558776855
# Clauses satisfied: 90
# 195 ------------------------
# iteration 0
# truth -0.802277785625301
# n satisfied 80
# iteration 1000
# truth -0.9380777841986526
# n satisfied 90
# iteration 2000
# truth -0.9380872808756542
# n satisfied 90
# Time taken: 1.3180313110351562
# Clauses satisfied: 90
# 196 ------------------------
# iteration 0
# truth -0.7808148631297736
# n satisfied 76
# Solution found in 100 iterations
# Time taken: 0.048099517822265625
# Clauses satisfied: 91
# 197 ------------------------
# iteration 0
# truth -0.8615539479706887
# n satisfied 83
# Solution found in 100 iterations
# Time taken: 0.0461583137512207
# Clauses satisfied: 91
# 198 ------------------------
# iteration 0
# truth -0.7808620928063106
# n satisfied 73
# Solution found in 100 iterations
# Time taken: 0.04179024696350098
# Clauses satisfied: 91
# 199 ------------------------
# iteration 0
# truth -0.8103396867697495
# n satisfied 84
# iteration 1000
# truth -0.9152365377610908
# n satisfied 89
# iteration 2000
# truth -0.9152433333664387
# n satisfied 89
# Time taken: 1.355250597000122
# Clauses satisfied: 89
# 200 ------------------------
# iteration 0
# truth -0.8170339817317761
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.07688426971435547
# Clauses satisfied: 91
# 201 ------------------------
# iteration 0
# truth -0.8197615374593699
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.09909486770629883
# Clauses satisfied: 91
# 202 ------------------------
# iteration 0
# truth -0.8512008837551231
# n satisfied 80
# iteration 1000
# truth -0.9386632458319282
# n satisfied 90
# iteration 2000
# truth -0.9386732872707992
# n satisfied 90
# Time taken: 2.4334027767181396
# Clauses satisfied: 90
# 203 ------------------------
# iteration 0
# truth -0.8331908226964293
# n satisfied 84
# iteration 1000
# truth -0.9362976027366892
# n satisfied 90
# iteration 2000
# truth -0.9363560568274633
# n satisfied 90
# Time taken: 1.7630174160003662
# Clauses satisfied: 90
# 204 ------------------------
# iteration 0
# truth -0.7162552745759394
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.04691004753112793
# Clauses satisfied: 91
# 205 ------------------------
# iteration 0
# truth -0.8137208313655553
# n satisfied 81
# iteration 1000
# truth -0.9370860468361636
# n satisfied 90
# iteration 2000
# truth -0.93709556206446
# n satisfied 90
# Time taken: 2.056598424911499
# Clauses satisfied: 90
# 206 ------------------------
# iteration 0
# truth -0.7266778227500499
# n satisfied 77
# Solution found in 100 iterations
# Time taken: 0.05356407165527344
# Clauses satisfied: 91
# 207 ------------------------
# iteration 0
# truth -0.8292125080098915
# n satisfied 83
# Solution found in 600 iterations
# Time taken: 0.5535094738006592
# Clauses satisfied: 91
# 208 ------------------------
# iteration 0
# truth -0.78423842259504
# n satisfied 78
# iteration 1000
# truth -0.9263876322414479
# n satisfied 90
# iteration 2000
# truth -0.9264232423428297
# n satisfied 90
# Time taken: 1.854198694229126
# Clauses satisfied: 90
# 209 ------------------------
# iteration 0
# truth -0.760470229841675
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.050908565521240234
# Clauses satisfied: 91
# 210 ------------------------
# iteration 0
# truth -0.8513591696956762
# n satisfied 86
# iteration 1000
# truth -0.9358026249862443
# n satisfied 90
# iteration 2000
# truth -0.9358098035426663
# n satisfied 90
# Time taken: 1.691154956817627
# Clauses satisfied: 90
# 211 ------------------------
# iteration 0
# truth -0.7993488568949344
# n satisfied 83
# Solution found in 100 iterations
# Time taken: 0.05672740936279297
# Clauses satisfied: 91
# 212 ------------------------
# iteration 0
# truth -0.823835853217827
# n satisfied 81
# iteration 1000
# truth -0.9461333898263341
# n satisfied 90
# iteration 2000
# truth -0.9461459135269692
# n satisfied 90
# Time taken: 1.6536509990692139
# Clauses satisfied: 90
# 213 ------------------------
# iteration 0
# truth -0.8005958185720671
# n satisfied 82
# iteration 1000
# truth -0.9012900481215705
# n satisfied 89
# iteration 2000
# truth -0.9013035287431779
# n satisfied 89
# Time taken: 1.5102753639221191
# Clauses satisfied: 89
# 214 ------------------------
# iteration 0
# truth -0.801111491277992
# n satisfied 84
# Solution found in 100 iterations
# Time taken: 0.04213380813598633
# Clauses satisfied: 91
# 215 ------------------------
# iteration 0
# truth -0.7949652776819447
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.04482412338256836
# Clauses satisfied: 91
# 216 ------------------------
# iteration 0
# truth -0.8063004875631216
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.043152570724487305
# Clauses satisfied: 91
# 217 ------------------------
# iteration 0
# truth -0.7937768360513857
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.04784727096557617
# Clauses satisfied: 91
# 218 ------------------------
# iteration 0
# truth -0.7921418437800958
# n satisfied 82
# Solution found in 200 iterations
# Time taken: 0.11182236671447754
# Clauses satisfied: 91
# 219 ------------------------
# iteration 0
# truth -0.7542606250068228
# n satisfied 79
# Solution found in 100 iterations
# Time taken: 0.09046792984008789
# Clauses satisfied: 91
# 220 ------------------------
# iteration 0
# truth -0.8122530600013042
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.04533696174621582
# Clauses satisfied: 91
# 221 ------------------------
# iteration 0
# truth -0.8596567679217781
# n satisfied 86
# iteration 1000
# truth -0.9280210719288826
# n satisfied 90
# iteration 2000
# truth -0.9280295745302815
# n satisfied 90
# Time taken: 1.7041196823120117
# Clauses satisfied: 90
# 222 ------------------------
# iteration 0
# truth -0.8478254236655596
# n satisfied 86
# iteration 1000
# truth -0.9358781821199629
# n satisfied 90
# iteration 2000
# truth -0.9358890876449193
# n satisfied 90
# Time taken: 1.9597456455230713
# Clauses satisfied: 90
# 223 ------------------------
# iteration 0
# truth -0.8262209968802499
# n satisfied 80
# iteration 1000
# truth -0.9374585103432992
# n satisfied 90
# iteration 2000
# truth -0.9374680972283859
# n satisfied 90
# Time taken: 1.9483463764190674
# Clauses satisfied: 90
# 224 ------------------------
# iteration 0
# truth -0.824925164431155
# n satisfied 82
# iteration 1000
# truth -0.9406977522564758
# n satisfied 90
# iteration 2000
# truth -0.9407080971606497
# n satisfied 90
# Time taken: 1.624511957168579
# Clauses satisfied: 90
# 225 ------------------------
# iteration 0
# truth -0.8235307851636264
# n satisfied 79
# Solution found in 100 iterations
# Time taken: 0.05619215965270996
# Clauses satisfied: 91
# 226 ------------------------
# iteration 0
# truth -0.8144214950122307
# n satisfied 79
# Solution found in 100 iterations
# Time taken: 0.04854702949523926
# Clauses satisfied: 91
# 227 ------------------------
# iteration 0
# truth -0.7929130288209507
# n satisfied 76
# Solution found in 100 iterations
# Time taken: 0.04955339431762695
# Clauses satisfied: 91
# 228 ------------------------
# iteration 0
# truth -0.8021883108778455
# n satisfied 81
# iteration 1000
# truth -0.9355817451969503
# n satisfied 90
# iteration 2000
# truth -0.9355896870748033
# n satisfied 90
# Time taken: 1.3724732398986816
# Clauses satisfied: 90
# 229 ------------------------
# iteration 0
# truth -0.809972403433145
# n satisfied 81
# iteration 1000
# truth -0.9148687897124359
# n satisfied 89
# iteration 2000
# truth -0.9148703898379036
# n satisfied 89
# Time taken: 1.3936758041381836
# Clauses satisfied: 89
# 230 ------------------------
# iteration 0
# truth -0.8025645136699298
# n satisfied 79
# iteration 1000
# truth -0.9310203416135192
# n satisfied 90
# iteration 2000
# truth -0.9310283729143173
# n satisfied 90
# Time taken: 1.968804121017456
# Clauses satisfied: 90
# 231 ------------------------
# iteration 0
# truth -0.7803077603121035
# n satisfied 74
# iteration 1000
# truth -0.9363259265740976
# n satisfied 90
# iteration 2000
# truth -0.936334101778419
# n satisfied 90
# Time taken: 1.786536455154419
# Clauses satisfied: 90
# 232 ------------------------
# iteration 0
# truth -0.8096427028152309
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.09700202941894531
# Clauses satisfied: 91
# 233 ------------------------
# iteration 0
# truth -0.8012873597587128
# n satisfied 76
# iteration 1000
# truth -0.9365941667685761
# n satisfied 90
# iteration 2000
# truth -0.9366082108885646
# n satisfied 90
# Time taken: 1.8143243789672852
# Clauses satisfied: 90
# 234 ------------------------
# iteration 0
# truth -0.8103158333925208
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.07952690124511719
# Clauses satisfied: 91
# 235 ------------------------
# iteration 0
# truth -0.8087319626974653
# n satisfied 75
# Solution found in 200 iterations
# Time taken: 0.09362244606018066
# Clauses satisfied: 91
# 236 ------------------------
# iteration 0
# truth -0.7700306836700457
# n satisfied 80
# iteration 1000
# truth -0.9369040821070579
# n satisfied 90
# iteration 2000
# truth -0.9369141021329054
# n satisfied 90
# Time taken: 2.394402027130127
# Clauses satisfied: 90
# 237 ------------------------
# iteration 0
# truth -0.8240809239219778
# n satisfied 84
# iteration 1000
# truth -0.934623373614688
# n satisfied 90
# iteration 2000
# ...
# 682 ------------------------
# iteration 0
# truth -0.8181650290239889
# n satisfied 79
# iteration 1000
# truth -0.9445642567893865
# n satisfied 90
# iteration 2000
# truth -0.9445771640118774
# n satisfied 90
# Time taken: 1.1167845726013184
# Clauses satisfied: 90
# 683 ------------------------
# iteration 0
# truth -0.8356483691986958
# n satisfied 86
# Solution found in 100 iterations
# Time taken: 0.04184722900390625
# Clauses satisfied: 91
# 684 ------------------------
# iteration 0
# truth -0.7528694975450816
# n satisfied 77
# iteration 1000
# truth -0.9383712242900848
# n satisfied 90
# iteration 2000
# truth -0.9383819460626569
# n satisfied 90
# Time taken: 1.2579920291900635
# Clauses satisfied: 90
# 685 ------------------------
# iteration 0
# truth -0.7745129774877466
# n satisfied 79
# iteration 1000
# truth -0.907284265525789
# n satisfied 89
# iteration 2000
# truth -0.9072929953147151
# n satisfied 89
# Time taken: 1.3810930252075195
# Clauses satisfied: 89
# 686 ------------------------
# iteration 0
# truth -0.7865463714611163
# n satisfied 79
# Solution found in 100 iterations
# Time taken: 0.04785895347595215
# Clauses satisfied: 91
# 687 ------------------------
# iteration 0
# truth -0.8252508196606727
# n satisfied 82
# iteration 1000
# truth -0.9402158376887695
# n satisfied 90
# iteration 2000
# truth -0.9402288991459677
# n satisfied 90
# Time taken: 1.3337986469268799
# Clauses satisfied: 90
# 688 ------------------------
# iteration 0
# truth -0.8257602700417321
# n satisfied 83
# Solution found in 100 iterations
# Time taken: 0.04777097702026367
# Clauses satisfied: 91
# 689 ------------------------
# iteration 0
# truth -0.8212190523304204
# n satisfied 82
# iteration 1000
# truth -0.9075676997253773
# n satisfied 89
# iteration 2000
# truth -0.907570477656561
# n satisfied 89
# Time taken: 1.3426735401153564
# Clauses satisfied: 89
# 690 ------------------------
# iteration 0
# truth -0.7801249095941334
# n satisfied 81
# iteration 1000
# truth -0.9369490531691298
# n satisfied 90
# iteration 2000
# truth -0.9369644777048791
# n satisfied 90
# Time taken: 3.218424081802368
# Clauses satisfied: 90
# 691 ------------------------
# iteration 0
# truth -0.8245522965341024
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.07631397247314453
# Clauses satisfied: 91
# 692 ------------------------
# iteration 0
# truth -0.7602632965016556
# n satisfied 77
# iteration 1000
# truth -0.9370259279204516
# n satisfied 90
# iteration 2000
# truth -0.9370334172000662
# n satisfied 90
# Time taken: 2.624082326889038
# Clauses satisfied: 90
# 693 ------------------------
# iteration 0
# truth -0.7523534264009429
# n satisfied 75
# Solution found in 100 iterations
# Time taken: 0.18628883361816406
# Clauses satisfied: 91
# 694 ------------------------
# iteration 0
# truth -0.7714617209059593
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.06176304817199707
# Clauses satisfied: 91
# 695 ------------------------
# iteration 0
# truth -0.8230383612970344
# n satisfied 84
# Solution found in 100 iterations
# Time taken: 0.054468393325805664
# Clauses satisfied: 91
# 696 ------------------------
# iteration 0
# truth -0.7880063128476053
# n satisfied 75
# Solution found in 100 iterations
# Time taken: 0.06869292259216309
# Clauses satisfied: 91
# 697 ------------------------
# iteration 0
# truth -0.8017727384861647
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.1465597152709961
# Clauses satisfied: 91
# 698 ------------------------
# iteration 0
# truth -0.802171228561191
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.09487771987915039
# Clauses satisfied: 91
# 699 ------------------------
# iteration 0
# truth -0.8273856497803396
# n satisfied 83
# iteration 1000
# truth -0.9356795364390075
# n satisfied 90
# iteration 2000
# truth -0.9357086857382133
# n satisfied 90
# Time taken: 3.4651527404785156
# Clauses satisfied: 90
# 700 ------------------------
# iteration 0
# truth -0.8074247667472811
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.06650543212890625
# Clauses satisfied: 91
# 701 ------------------------
# iteration 0
# truth -0.7908709777175148
# n satisfied 83
# iteration 1000
# truth -0.9324483714594554
# n satisfied 90
# Solution found in 1800 iterations
# Time taken: 2.7917261123657227
# Clauses satisfied: 91
# 702 ------------------------
# iteration 0
# truth -0.8045563097352304
# n satisfied 79
# iteration 1000
# truth -0.9081442591968224
# n satisfied 89
# iteration 2000
# truth -0.9326825082013463
# n satisfied 90
# Time taken: 2.272162675857544
# Clauses satisfied: 90
# 703 ------------------------
# iteration 0
# truth -0.7868820121940284
# n satisfied 80
# iteration 1000
# truth -0.9367278015956837
# n satisfied 90
# iteration 2000
# truth -0.9367393829974919
# n satisfied 90
# Time taken: 2.3106610774993896
# Clauses satisfied: 90
# 704 ------------------------
# iteration 0
# truth -0.8296399431907766
# n satisfied 77
# iteration 1000
# truth -0.9291406573469801
# n satisfied 90
# iteration 2000
# truth -0.9291468842252142
# n satisfied 90
# Time taken: 1.7553842067718506
# Clauses satisfied: 90
# 705 ------------------------
# iteration 0
# truth -0.797493948227698
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.044161319732666016
# Clauses satisfied: 91
# 706 ------------------------
# iteration 0
# truth -0.816567266989686
# n satisfied 79
# iteration 1000
# truth -0.9387407111388036
# n satisfied 90
# iteration 2000
# truth -0.938748992617664
# n satisfied 90
# Time taken: 1.6493659019470215
# Clauses satisfied: 90
# 707 ------------------------
# iteration 0
# truth -0.822568546278744
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.05091047286987305
# Clauses satisfied: 91
# 708 ------------------------
# iteration 0
# truth -0.8289210393816951
# n satisfied 79
# iteration 1000
# truth -0.9341861335649339
# n satisfied 90
# iteration 2000
# truth -0.9341951231989352
# n satisfied 90
# Time taken: 1.9336776733398438
# Clauses satisfied: 90
# 709 ------------------------
# iteration 0
# truth -0.7770867817273852
# n satisfied 79
# iteration 1000
# truth -0.9213726059458002
# n satisfied 90
# iteration 2000
# truth -0.9213792138798446
# n satisfied 90
# Time taken: 1.478201150894165
# Clauses satisfied: 90
# 710 ------------------------
# iteration 0
# truth -0.7315879098057698
# n satisfied 75
# iteration 1000
# truth -0.9324775495347113
# n satisfied 90
# iteration 2000
# truth -0.9324833879979543
# n satisfied 90
# Time taken: 1.172703504562378
# Clauses satisfied: 90
# 711 ------------------------
# iteration 0
# truth -0.8031873061679253
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.04202723503112793
# Clauses satisfied: 91
# 712 ------------------------
# iteration 0
# truth -0.7381023836204614
# n satisfied 74
# iteration 1000
# truth -0.9381245104453332
# n satisfied 90
# iteration 2000
# truth -0.9381923642796333
# n satisfied 90
# Time taken: 1.526252031326294
# Clauses satisfied: 90
# 713 ------------------------
# iteration 0
# truth -0.8027550815765012
# n satisfied 83
# Solution found in 200 iterations
# Time taken: 0.10739421844482422
# Clauses satisfied: 91
# 714 ------------------------
# iteration 0
# truth -0.7989593559474716
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.052748918533325195
# Clauses satisfied: 91
# 715 ------------------------
# iteration 0
# truth -0.7563298981160441
# n satisfied 77
# Solution found in 500 iterations
# Time taken: 0.24656939506530762
# Clauses satisfied: 91
# 716 ------------------------
# iteration 0
# truth -0.7967398173948363
# n satisfied 82
# iteration 1000
# truth -0.9375987048777934
# n satisfied 90
# iteration 2000
# truth -0.9376092760909654
# n satisfied 90
# Time taken: 1.4706227779388428
# Clauses satisfied: 90
# 717 ------------------------
# iteration 0
# truth -0.7774502111802901
# n satisfied 81
# iteration 1000
# truth -0.9275254666218811
# n satisfied 90
# iteration 2000
# truth -0.9275351599460897
# n satisfied 90
# Time taken: 1.9199001789093018
# Clauses satisfied: 90
# 718 ------------------------
# iteration 0
# truth -0.7995549756468108
# n satisfied 82
# iteration 1000
# truth -0.9253663245846506
# n satisfied 90
# iteration 2000
# truth -0.9253715538890249
# n satisfied 90
# Time taken: 1.4499237537384033
# Clauses satisfied: 90
# 719 ------------------------
# iteration 0
# truth -0.8455055548766017
# n satisfied 84
# iteration 1000
# truth -0.929930590169908
# n satisfied 90
# iteration 2000
# truth -0.9299391335565677
# n satisfied 90
# Time taken: 1.553415060043335
# Clauses satisfied: 90
# 720 ------------------------
# iteration 0
# truth -0.8017772229838551
# n satisfied 75
# Solution found in 100 iterations
# Time taken: 0.050394535064697266
# Clauses satisfied: 91
# 721 ------------------------
# iteration 0
# truth -0.7108638043433684
# n satisfied 76
# Solution found in 100 iterations
# Time taken: 0.05080008506774902
# Clauses satisfied: 91
# 722 ------------------------
# iteration 0
# truth -0.7836468913251671
# n satisfied 82
# iteration 1000
# truth -0.9329134496406372
# n satisfied 90
# iteration 2000
# truth -0.932921103708849
# n satisfied 90
# Time taken: 1.40079927444458
# Clauses satisfied: 90
# 723 ------------------------
# iteration 0
# truth -0.8404053170097482
# n satisfied 82
# iteration 1000
# truth -0.914846615075497
# n satisfied 89
# iteration 2000
# truth -0.9148504930216672
# n satisfied 89
# Time taken: 1.3971202373504639
# Clauses satisfied: 89
# 724 ------------------------
# iteration 0
# truth -0.7484657654853997
# n satisfied 74
# iteration 1000
# truth -0.9104299389314262
# n satisfied 89
# iteration 2000
# truth -0.9104490527772952
# n satisfied 89
# Time taken: 1.4729344844818115
# Clauses satisfied: 89
# 725 ------------------------
# iteration 0
# truth -0.780560918404529
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.05117034912109375
# Clauses satisfied: 91
# 726 ------------------------
# iteration 0
# truth -0.8524821174452346
# n satisfied 84
# Solution found in 100 iterations
# Time taken: 0.051439762115478516
# Clauses satisfied: 91
# 727 ------------------------
# iteration 0
# truth -0.7798177915029612
# n satisfied 78
# iteration 1000
# truth -0.9338370436227316
# n satisfied 90
# iteration 2000
# truth -0.9338430570207614
# n satisfied 90
# Time taken: 1.4539906978607178
# Clauses satisfied: 90
# 728 ------------------------
# iteration 0
# truth -0.8035809850487364
# n satisfied 81
# iteration 1000
# truth -0.9433179850680204
# n satisfied 90
# iteration 2000
# truth -0.9433279520683773
# n satisfied 90
# Time taken: 1.4003667831420898
# Clauses satisfied: 90
# 729 ------------------------
# iteration 0
# truth -0.784714743844845
# n satisfied 78
# iteration 1000
# truth -0.9072572880056242
# n satisfied 89
# iteration 2000
# truth -0.9072592751758798
# n satisfied 89
# Time taken: 1.4225196838378906
# Clauses satisfied: 89
# 730 ------------------------
# iteration 0
# truth -0.8131166207941759
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.05397748947143555
# Clauses satisfied: 91
# 731 ------------------------
# iteration 0
# truth -0.8260157791523399
# n satisfied 84
# Solution found in 100 iterations
# Time taken: 0.05245399475097656
# Clauses satisfied: 91
# 732 ------------------------
# iteration 0
# truth -0.7800894079587162
# n satisfied 76
# Solution found in 100 iterations
# Time taken: 0.05177950859069824
# Clauses satisfied: 91
# 733 ------------------------
# iteration 0
# truth -0.8516313749316622
# n satisfied 81
# Solution found in 400 iterations
# Time taken: 0.1827995777130127
# Clauses satisfied: 91
# 734 ------------------------
# iteration 0
# truth -0.783305770367699
# n satisfied 79
# Solution found in 100 iterations
# Time taken: 0.0439300537109375
# Clauses satisfied: 91
# 735 ------------------------
# iteration 0
# truth -0.8228235562713753
# n satisfied 76
# iteration 1000
# truth -0.9399644368748721
# n satisfied 90
# iteration 2000
# truth -0.9400569501781623
# n satisfied 90
# Time taken: 1.504765510559082
# Clauses satisfied: 90
# 736 ------------------------
# iteration 0
# truth -0.7532962864004766
# n satisfied 79
# iteration 1000
# truth -0.9252092431666401
# n satisfied 90
# iteration 2000
# truth -0.9253078872173643
# n satisfied 90
# Time taken: 1.7625908851623535
# Clauses satisfied: 90
# 737 ------------------------
# iteration 0
# truth -0.7584446286913393
# n satisfied 77
# Solution found in 300 iterations
# Time taken: 0.45316314697265625
# Clauses satisfied: 91
# 738 ------------------------
# iteration 0
# truth -0.7926543344491467
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.049062490463256836
# Clauses satisfied: 91
# 739 ------------------------
# iteration 0
# truth -0.7825849334686938
# n satisfied 74
# Solution found in 100 iterations
# Time taken: 0.04792451858520508
# Clauses satisfied: 91
# 740 ------------------------
# iteration 0
# truth -0.839028865395483
# n satisfied 86
# iteration 1000
# truth -0.9167178952998942
# n satisfied 89
# iteration 2000
# truth -0.9167219000557612
# n satisfied 89
# Time taken: 1.5308806896209717
# Clauses satisfied: 89
# 741 ------------------------
# iteration 0
# truth -0.8173124447189437
# n satisfied 79
# Solution found in 100 iterations
# Time taken: 0.08481502532958984
# Clauses satisfied: 91
# 742 ------------------------
# iteration 0
# truth -0.7960557863073777
# n satisfied 80
# iteration 1000
# truth -0.928845807931116
# n satisfied 90
# iteration 2000
# truth -0.9288529999370599
# n satisfied 90
# Time taken: 2.1835246086120605
# Clauses satisfied: 90
# 743 ------------------------
# iteration 0
# truth -0.7602273193800257
# n satisfied 80
# iteration 1000
# truth -0.9137613890119404
# n satisfied 89
# iteration 2000
# truth -0.913768507589573
# n satisfied 89
# Time taken: 1.7262814044952393
# Clauses satisfied: 89
# 744 ------------------------
# iteration 0
# truth -0.7673479021880858
# n satisfied 80
# iteration 1000
# truth -0.9262302624135524
# n satisfied 90
# iteration 2000
# truth -0.9262412180587186
# n satisfied 90
# Time taken: 1.7055983543395996
# Clauses satisfied: 90
# 745 ------------------------
# iteration 0
# truth -0.804213860699375
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.05104255676269531
# Clauses satisfied: 91
# 746 ------------------------
# iteration 0
# truth -0.7823704764793268
# n satisfied 77
# Solution found in 100 iterations
# Time taken: 0.0508425235748291
# Clauses satisfied: 91
# 747 ------------------------
# iteration 0
# truth -0.7589169677583152
# n satisfied 75
# Solution found in 100 iterations
# Time taken: 0.048891305923461914
# Clauses satisfied: 91
# 748 ------------------------
# iteration 0
# truth -0.8085122619843269
# n satisfied 80
# Solution found in 100 iterations
# Time taken: 0.051392555236816406
# Clauses satisfied: 91
# 749 ------------------------
# iteration 0
# truth -0.8559034235411129
# n satisfied 84
# Solution found in 100 iterations
# Time taken: 0.04857635498046875
# Clauses satisfied: 91
# 750 ------------------------
# iteration 0
# truth -0.825795670164065
# n satisfied 77
# Solution found in 100 iterations
# Time taken: 0.05670475959777832
# Clauses satisfied: 91
# 751 ------------------------
# iteration 0
# truth -0.776661563885602
# n satisfied 77
# Solution found in 100 iterations
# Time taken: 0.051410675048828125
# Clauses satisfied: 91
# 752 ------------------------
# iteration 0
# truth -0.8195441619781982
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.054155588150024414
# Clauses satisfied: 91
# 753 ------------------------
# iteration 0
# truth -0.8214320157455666
# n satisfied 82
# Solution found in 100 iterations
# Time taken: 0.052594900131225586
# Clauses satisfied: 91
# 754 ------------------------
# iteration 0
# truth -0.8004153945308348
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.05116605758666992
# Clauses satisfied: 91
# 755 ------------------------
# iteration 0
# truth -0.748412777451493
# n satisfied 76
# Solution found in 100 iterations
# Time taken: 0.051654815673828125
# Clauses satisfied: 91
# 756 ------------------------
# iteration 0
# truth -0.7848867148903278
# n satisfied 77
# Solution found in 100 iterations
# Time taken: 0.05349874496459961
# Clauses satisfied: 91
# 757 ------------------------
# iteration 0
# truth -0.800448033263336
# n satisfied 81
# Solution found in 100 iterations
# Time taken: 0.051061153411865234
# Clauses satisfied: 91
# 758 ------------------------
# iteration 0
# truth -0.7923508309290608
# n satisfied 78
# Solution found in 100 iterations
# Time taken: 0.050159454345703125
# Clauses satisfied: 91
# 759 ------------------------
# iteration 0
# truth -0.7696877528451381
# n satisfied 77
# iteration 1000
# truth -0.9452357377378056
# n satisfied 90
# iteration 2000
# truth -0.945244595406012
# n satisfied 90
# Time taken: 1.4273192882537842
# Clauses satisfied: 90
# 760 ------------------------
# iteration 0
# truth -0.7813460078772888
# n satisfied 76
# iteration 1000
# truth -0.9168288384337703
# n satisfied 89
# iteration 2000
# truth -0.9168333545068552
# n satisfied 89

# %%
def sigmoid(f):
    def _sigmoid(a, b):
        return f(a, b)
    return _sigmoid

S_SP = sigmoid(lambda a, b: 1 - (1-a) * (1 - b))
I_SP = sigmoid(lambda a, b: 1 - a + a * b)

print(S_SP(1, 0))
print(I_SP(1, 0))
# Out:
# 1
# 0
